# %% [markdown]
# # Midjourney Terragen
#
# Playing with the Midjourney Terragen keyword. Terragen is a powerful solution for building, rendering, and animating realistic natural environments. Create entire worlds from your imagination, or import real world terrain data sets and use Terragen to create the most realistic visualizations possible
#
# Follow us on AI Skunks Instagran (https://www.instagram.com/skunksai/) @ AI Skunks Github (https://github.com/aiskunks/aiskunks)
#
# Link to the Colab https://colab.research.google.com/drive/1TXefbFe9CWVzS0eInKgxXCgQw2F1Ldqk?usp=sharing

# %%
characters = [ 'Spider-Man', 'Captain America', 'Iron Man', 'Thor', 'Hulk', 'Doctor Strange', 'Black Panther', 'Wolverine', 'Luke Cage', 'Iron Fist', 'Jessica Jones', 'Punisher', 'Silver Surfer', 'Adam Warlock', 'Doctor Doom', 'Green Goblin', 'Captain America Winter Soldier', 'Captain Marvel', 'Ms. Marvel', 'Spider-Woman', 'Ms. Marvel', 'Moon Knight', 'Cloak and Dagger', 'Runaways', 'Jessica Drew', 'Shang-Chi', 'Elsa Bloodstone', 'America Chavez', 'Kamala Khan', 'Namor the Sub-Mariner', 'Harry Potter', 'Hermione Granger', 'Severus Snape', 'Voldemort', 'Sirius Black', 'Rubeus Hagrid', 'Draco Malfoy', 'Luna Lovegood', 'Bellatrix Lestrange', 'Parvati Patil', 'Padma Patil', 'Lavender Brown', 'Susan Bones', 'Sherlock Holmes', 'Darth Vader', 'Superman', 'Batman', 'Wonder Woman', 'Spider-Man', 'James Bond', 'Luke Skywalker', 'Atticus Finch', "Frankenstein's Monster", 'Peter Pan', 'Cinderella', 'Sleeping Beauty', 'Belle', 'Beast', 'Snow White', 'Pinocchio', 'The Little Mermaid', 'Aladdin', 'The Genie', 'Mulan', 'Simba', 'Mufasa', 'Buzz Lightyear', 'Wall-E', 'Dorothy Gale', 'The Tin Man', 'The Scarecrow', 'The Cowardly Lion', 'Alice', 'The Mad Hatter', 'The Queen of Hearts', 'The Wicked Witch of the West', 'The White Witch', 'Indiana Jones', 'The Joker', 'Catwoman', 'Ada Lovelace mathematician with a mechanical general-purpose computer the Analytical Engine', 'Isaac Newton', 'Albert Einstein', 'Galileo Galilei', 'Nikola Tesla', 'Alan Turing', 'James Clerk Maxwell', 'Alice Alice in Wonderland', 'Anna Karenina Anna Karenina', 'Anne Shirley Anne of Green Gables', 'Ariel The Little Mermaid', 'Arya Stark A Song of Ice and Fire', 'Bella Swan Twilight', 'Buffy Summers Buffy the Vampire Slayer', 'Carmen Sandiego Where in the World is Carmen Sandiego?', 'Catwoman Batman', 'Cersei Lannister A Song of Ice and Fire', 'Charlotte York Sex and the City', 'Cinderella Cinderella', 'Clarice Starling The Silence of the Lambs', 'Daenerys Targaryen A Song of Ice and Fire', 'Daisy Buchanan The Great Gatsby', 'Dorothy Gale The Wizard of Oz', 'Eowyn The Lord of the Rings', 'Hermione Granger Harry Potter', 'Holly Golightly Breakfast at Tiffanys', 'Hua Mulan Ballad of Mulan', 'Jane Eyre Jane Eyre', 'Jasmine Aladdin', 'Jean Grey X-Men', 'Jessica Rabbit Who Framed Roger Rabbit', 'Jo March Little Women', 'Juliet Capulet Romeo and Juliet', 'Katniss Everdeen The Hunger Games', 'Lady Macbeth Macbeth', 'Lara Croft Tomb Raider', 'Lisbeth Salander The Girl with the Dragon Tattoo', 'Lois Lane Superman', 'Lucy Pevensie The Chronicles of Narnia', 'Maleficent Sleeping Beauty', 'Mary Poppins Mary Poppins', 'Matilda Wormwood Matilda', 'Princess Leia Organa Star Wars', 'SpongeBob SquarePants', 'Patrick Star', 'Squidward Tentacles', 'Mr. Krabs', 'Sandy Cheeks', 'Plankton', 'Gary the Snail', 'Mrs. Puff', 'Pearl Krabs', 'Larry the Lobster', 'Mermaid Man', 'Barnacle Boy', 'Karen Plankton', 'Bubble Bass', 'Patchy the Pirate', 'Superman', 'Batman', 'Green Lantern', 'Supergirl', 'Batwoman', 'Harley Quinn', 'Poison Ivy', 'The Joker', 'Katana', 'Mario video game character', 'Luigi video game character', 'Link video game character', 'Zelda video game character', 'Samus Aran video game character', 'Donkey Kong video game character', 'Diddy Kong video game character', 'Yoshi video game character', 'Kirby video game character', 'Pikachu video game character', 'Charizard video game character', 'Sonic the Hedgehog video game character', 'Tails video game character', 'Knuckles video game character', 'Dr. Eggman video game character', 'Crash Bandicoot video game character', 'Spyro the Dragon video game character', 'Ratchet and Clank video game character', 'Jak and Daxter video game character', 'Nathan Drake video game character', 'Kratos video game character', 'Master Chief video game character', 'Cortana video game character', 'Marcus Fenix video game character', 'Aloy video game character', 'Lara Croft video game character', 'Tifa Lockhart video game character', 'Master Chief']

# %%
terrains = [
    "Terragen Mountain range with lakes",
    "Terragen Desert canyon",
    "Terragen Tropical rainforest",
    "Terragen Volcanic landscape",
    "Terragen Mars-like red planet",
    "Terragen Frozen tundra",
    "Terragen Underwater seascape",
    "Terragen Rugged coastline",
    "Terragen Alien landscape",
    "Terragen Island archipelago",
    "Terragen Lunar surface",
    "Terragen Grassy meadow with rolling hills",
    "Terragen Cave system",
    "Terragen Snowy mountain pass",
    "Terragen Swampy wetlands",
    "Terragen City skyline",
    "Terragen Fantasy castle atop a hill",
    "Terragen Abandoned ruins in a jungle",
    "Terragen Rural farmland",
    "Terragen Industrial wasteland",
    "Terragen Medieval village",
    "Terragen Futuristic metropolis",
    "Terragen Dystopian cityscape",
    "Terragen Steampunk city",
    "Terragen Asteroid field",
    "Terragen Forest at night with mist",
    "Terragen Sand dunes in a desert",
    "Terragen Beneath a giant redwood tree",
    "Terragen Aurora borealis over a mountain lake",
    "Terragen Iceberg in the ocean",
    "Terragen Gothic cathedral in a city",
    "Terragen Sunset over a lake",
    "Terragen Canyon with a river running through it"
]

# %%
terragens = [
    'Terragen',
    'Terragen Tundra Shifters | by Subterfugitive',
    'Terragen Taiga Shifters | by Subterfugitive',
    'Terragen Rainforest Shifters | by Subterfugitive',
    'Terragen Desert Shifters | by Subterfugitive',
    'Terragen Grassland Shifters | by Subterfugitive',
    'Terragen Savanna Shifters | by Subterfugitive',
    'Terragen Prairie Shifters | by Subterfugitive',
    'Terragen Arctic Shifters | by Subterfugitive',
    'Terragen Alpine Shifters | by Subterfugitive',
    'Terragen Wetland Shifters | by Subterfugitive',
    'Terragen Mangrove Shifters | by Subterfugitive',
    'Terragen Coral reef Shifters | by Subterfugitive',
    'Terragen Ocean Shifters | by Subterfugitive',
    'Terragen Sea Shifters | by Subterfugitive',
    'Terragen Estuary Shifters | by Subterfugitive',
    'Terragen River Shifters | by Subterfugitive',
    'Terragen Stream Shifters | by Subterfugitive',
    'Terragen Waterfall Shifters | by Subterfugitive',
    'Terragen Mountain Shifters | by Subterfugitive',
    'Terragen Volcano Shifters | by Subterfugitive',
    'Terragen Canyon Shifters | by Subterfugitive',
    'Terragen Valley Shifters | by Subterfugitive',
    'Terragen Plateau Shifters | by Subterfugitive',
    'Terragen Hill Shifters | by Subterfugitive',
    'Terragen Dune Shifters | by Subterfugitive',
    'Terragen Glacier Shifters | by Subterfugitive',
    'Terragen Fjord Shifters | by Subterfugitive',
    'Terragen Bay Shifters | by Subterfugitive',
    'Terragen Delta Shifters | by Subterfugitive',
    'Terragen Peninsula Shifters | by Subterfugitive',
    'Terragen Island Shifters | by Subterfugitive',
    'Terragen Cavern Shifters | by Subterfugitive',
    'Terragen Grotto Shifters | by Subterfugitive',
    'Terragen Lagoon Shifters | by Subterfugitive',
    'Terragen Marsh Shifters | by Subterfugitive',
    'Terragen Bog Shifters | by Subterfugitive',
    'Terragen Fen Shifters | by Subterfugitive',
    'Terragen Kelp forest Shifters | by Subterfugitive',
    'Terragen Ice shelf Shifters | by Subterfugitive',
    'Terragen Salt flat Shifters | by Subterfugitive',
    'Terragen by Subterfugitive'            
    'Terragen Rain Shifters | by Subterfugitive'           
           ]

# %%
outfits = [
    'T-shirt and jeans',
    'Little black dress',
    'Maxi dress',
    'Midi dress',
    'Mini skirt and crop top',
    'Jumpsuit',
    'Romper',
    'Blouse and pants',
    'Suit and tie',
    'Cocktail dress',
    'Ball gown',
    'Sweatpants and hoodie',
    'Leggings and tunic',
    'Hoodie and shorts',
    'Tank top and shorts',
    'Polo shirt and khakis',
    'Cardigan and jeans',
    'Blazer and skirt',
    'Bodysuit and jeans',
    'Crop top and high-waisted pants',
    'Pajama set',
    'Sundress',
    'Bikini and cover-up',
    'Maxi skirt and tank top',
    'Overalls',
    'Denim jacket and shorts',
    'Turtleneck and slacks',
    'Wrap dress',
    'Peplum top and pencil skirt',
    'Culottes and sweater',
    'Sheath dress',
    'Off-the-shoulder top and skirt',
    'One-shoulder dress',
    'Halter top and shorts',
    'Boyfriend jeans and blazer',
    'Jeggings and tunic',
    'Long coat and boots',
    'Fleece pullover and leggings',
    'Pleated skirt and sweater',
    'Leather jacket and jeans',
    'Cropped sweater and high-waisted jeans',
    'Swing dress',
    'Cargo pants and tank top',
    'A-line dress',
    'Flannel shirt and jeans',
    'Striped shirt and shorts',
    'Tank top and maxi skirt',
    'Empire-waist dress',
    'Sequin dress',
    'Tube top and skirt',
    'Wide-leg pants and crop top',
    'Sweatshirt dress',
    'Kimono and jeans',
    'Plaid shirt and leggings',
    'Corduroy jacket and pants'
]

# %%
vacation_places = [
    "Paris, France",
    "Barcelona, Spain",
    "Rome, Italy",
    "Athens, Greece",
    "Istanbul, Turkey",
    "Bangkok, Thailand",
    "Tokyo, Japan",
    "Kyoto, Japan",
    "Sydney, Australia",
    "Melbourne, Australia",
    "Auckland, New Zealand",
    "Queenstown, New Zealand",
    "Vancouver, Canada",
    "Toronto, Canada",
    "New York City, USA",
    "Miami, USA",
    "Los Angeles, USA",
    "San Francisco, USA",
    "Las Vegas, USA",
    "Honolulu, USA",
    "Cancun, Mexico",
    "Puerto Vallarta, Mexico",
    "Montreal, Canada",
    "Quebec City, Canada",
    "Amsterdam, Netherlands",
    "Berlin, Germany",
    "London, UK",
    "Edinburgh, UK",
    "Dublin, Ireland",
    "Reykjavik, Iceland",
    "Oslo, Norway",
    "Stockholm, Sweden",
    "Copenhagen, Denmark",
    "Helsinki, Finland",
    "St. Petersburg, Russia",
    "Moscow, Russia",
    "Dubai, UAE",
    "Abu Dhabi, UAE",
    "Cairo, Egypt",
    "Marrakesh, Morocco",
    "Cape Town, South Africa",
    "Johannesburg, South Africa",
    "Rio de Janeiro, Brazil",
    "Buenos Aires, Argentina",
    "Santiago, Chile",
    "Machu Picchu, Peru",
    "Cusco, Peru",
    "Lima, Peru",
    "San Juan, Puerto Rico",
    "Bali, Indonesia",
    "Phuket, Thailand",
    "Krabi, Thailand",
    "Chiang Mai, Thailand",
    "Siem Reap, Cambodia",
    "Hanoi, Vietnam",
    "Ho Chi Minh City, Vietnam",
    "Singapore",
    "Hong Kong",
    "Taipei, Taiwan",
    "Seoul, South Korea",
    "Jeju Island, South Korea",
    "Melbourne, Australia",
    "Queenstown, New Zealand",
    "Bora Bora, French Polynesia",
    "Fiji",
    "Santorini, Greece",
    "Mykonos, Greece",
    "Barbados",
    "Jamaica",
    "Puerto Rico",
    "Hawaii, USA",
    "Alaska, USA",
    "Banff, Canada",
    "Whistler, Canada",
    "Lucerne, Switzerland",
    "Zermatt, Switzerland",
    "Vienna, Austria",
    "Salzburg, Austria",
    "Florence, Italy",
    "Venice, Italy",
    "Naples, Italy",
    "Siena, Italy",
    "Krakow, Poland",
    "Warsaw, Poland",
    "Bruges, Belgium",
    "Brussels, Belgium",
    "Dubrovnik, Croatia",
    "Split, Croatia",
    "Sarajevo, Bosnia and Herzegovina",
    "Prague, Czech Republic",
    "Budapest, Hungary",
    "Cologne, Germany",
    "Munich, Germany",
    "Hamburg, Germany",
    "Cannes, France",
    "Nice, France",
    "Monte Carlo, Monaco",
    "Madrid, Spain",
    "Seville, Spain",
    "Granada, Spain",
    "Lisbon, Portugal"]

fictional_places = [
    "Hogwarts School of Witchcraft and Wizardry (Harry Potter)",
    "Middle-earth (The Lord of the Rings)",
    "Narnia (The Chronicles of Narnia)",
    "Westeros (A Song of Ice and Fire)",
    "Hyrule (The Legend of Zelda)",
    "Neverland (Peter Pan)",
    "Wonderland (Alice's Adventures in Wonderland)",
    "Oz (The Wonderful Wizard of Oz)",
    "Discworld (Discworld series)",
    "Pandora (Avatar)",
    "Atlantis (Atlantis: The Lost Empire)",
    "Avalon (Arthurian legends)",
    "Shangri-La (Lost Horizon)",
    "Gotham City (Batman comics)",
    "Metropolis (Superman comics)",
    "The Shire (The Lord of the Rings)",
    "Gondor (The Lord of the Rings)",
    "Rivendell (The Lord of the Rings)",
    "Mordor (The Lord of the Rings)",
    "Helm's Deep (The Lord of the Rings)",
    "Hogsmeade (Harry Potter)",
    "Diagon Alley (Harry Potter)",
    "The Forbidden Forest (Harry Potter)",
    "The Burrow (Harry Potter)",
    "Platform 9 3/4 (Harry Potter)",
    "Willy Wonka's Chocolate Factory (Charlie and the Chocolate Factory)",
    "Haddonfield (Halloween)",
    "Amity Island (Jaws)",
    "Hill House (The Haunting of Hill House)",
    "Sleepy Hollow (The Legend of Sleepy Hollow)",
    "Whoville (How the Grinch Stole Christmas!)",
    "Naboo (Star Wars)",
    "Tatooine (Star Wars)",
    "Hoth (Star Wars)",
    "Endor (Star Wars)",
    "Coruscant (Star Wars)",
    "The Death Star (Star Wars)",
    "Hogwarts Express (Harry Potter)",
    "The Great Hall (Harry Potter)",
    "The Chamber of Secrets (Harry Potter)",
    "The Room of Requirement (Harry Potter)",
    "The Quidditch Pitch (Harry Potter)",
    "The Ministry of Magic (Harry Potter)",
    "Mount Doom (The Lord of the Rings)",
    "The Prancing Pony (The Lord of the Rings)",
    "The Mines of Moria (The Lord of the Rings)",
    "The Black Gate (The Lord of the Rings)",
    "The Lonely Mountain (The Hobbit)",
    "Rapture (Bioshock)",
    "Columbia (Bioshock Infinite)",
    "Zanarkand (Final Fantasy X)",
    "Midgar (Final Fantasy VII)",
    "Spira (Final Fantasy X)",
    "Hydaelyn (Final Fantasy XIV)",
    "Azeroth (World of Warcraft)",
    "Pandaria (World of Warcraft)",
    "Stormwind City (World of Warcraft)",
    "Orgrimmar (World of Warcraft)",
    "Eorzea (Final Fantasy XIV)",
    "Gilead (The Dark Tower series)",
    "Mid-World (The Dark Tower series)",
    "Lud (The Dark Tower series)",
    "Harrowing (The Dark Tower series)",
    "The Barrow-Downs (The Lord of the Rings)",
    "The Tower of Cirith Ungol (The Lord of the Rings)",
    "Castle Rock (Stephen King novels)",
    "Derry, Maine (Stephen King novels)",
    "Mid-World (Stephen King novels)",
    "Federation space (Star Trek)"]

photogenic_places = [
    "Central Park, New York City, USA",
    "Shibuya Crossing, Tokyo, Japan",
    "La Rambla, Barcelona, Spain",
    "The Louvre Museum, Paris, France",
    "The Colosseum, Rome, Italy",
    "Tower Bridge, London, UK",
    "Times Square, New York City, USA",
    "The Spanish Steps, Rome, Italy",
    "The Brooklyn Bridge, New York City, USA",
    "The Trevi Fountain, Rome, Italy",
    "The Palace of Versailles, Versailles, France",
    "The Guggenheim Museum, Bilbao, Spain",
    "The Santa Monica Pier, Santa Monica, USA",
    "The National Mall, Washington D.C., USA",
    "The Art Institute of Chicago, Chicago, USA",
    "The Brandenburg Gate, Berlin, Germany",
    "The Sydney Opera House, Sydney, Australia",
    "The Burj Khalifa, Dubai, UAE",
    "The Petronas Twin Towers, Kuala Lumpur, Malaysia",
    "The Marina Bay Sands, Singapore",
    "The Golden Gate Bridge, San Francisco, USA",
    "The Empire State Building, New York City, USA",
    "The London Eye, London, UK",
    "The Tower of London, London, UK",
    "The Arc de Triomphe, Paris, France",
    "The Notre-Dame Cathedral, Paris, France",
    "The Sagrada Familia, Barcelona, Spain",
    "The Alhambra, Granada, Spain",
    "The Grand Palace, Bangkok, Thailand",
    "The Forbidden City, Beijing, China",
    "The Tokyo Tower, Tokyo, Japan",
    "The Space Needle, Seattle, USA",
    "The Hollywood Sign, Los Angeles, USA",
    "The CN Tower, Toronto, Canada",
    "The Opera Garnier, Paris, France",
    "The Rijksmuseum, Amsterdam, Netherlands",
    "The Van Gogh Museum, Amsterdam, Netherlands",
    "The EYE Film Museum, Amsterdam, Netherlands",
    "The Charles Bridge, Prague, Czech Republic",
    "The Wawel Castle, Krakow, Poland",
    "The St. Stephen's Basilica, Budapest, Hungary",
    "The Parliament Building, Budapest, Hungary",
    "The La Scala Theater, Milan, Italy",
    "The San Francisco Cable Cars, San Francisco, USA",
    "The Santa Fe Art District, Denver, USA",
    "The Las Vegas Strip, Las Vegas, USA",
    "The Pike Place Market, Seattle, USA",
    "The Grand Bazaar, Istanbul, Turkey",
    "The Blue Mosque, Istanbul, Turkey",
    "The Basilica di San Marco, Venice, Italy",
    "The Pantheon, Rome, Italy",
    "The Piazza del Popolo, Rome, Italy",
    "The Piazza Navona, Rome, Italy",
    "The Piazza della Signoria, Florence, Italy",
    "The Uffizi Gallery, Florence, Italy",
    "The Leaning Tower of Pisa, Pisa, Italy",
    "The Piazza San Marco, Venice, Italy",
    "The Fisherman's Bastion, Budapest, Hungary",
    "The Park Güell, Barcelona, Spain",
    "The Royal Palace of Madrid, Madrid, Spain",
    "The Parthenon, Athens, Greece",
    "The Odeon of Herodes Atticus, Athens, Greece",
    "The Plaka District, Athens, Greece",
    "The Blue Mosque, Istanbul, Turkey",
    "The Basilica di San Marco, Venice, Italy",
    "The Pantheon, Rome, Italy",
    "The Piazza del Popolo, Rome, Italy",
    "The Piazza Navona, Rome, Italy",
    "The Piazza della Signoria, Florence, Italy",
    "The Uffizi Gallery, Florence, Italy",
    "The Leaning Tower of Pisa, Pisa, Italy",
    "The Piazza San Marco, Venice, Italy",
    "The Fisherman's Bastion, Budapest, Hungary",
    "The Park Güell, Barcelona, Spain",
    "The Royal Palace of Madrid, Madrid, Spain",
    "The Parthenon, Athens, Greece",
    "The Odeon of Herodes Atticus, Athens, Greece",
    "The Plaka District, Athens, Greece",
"Trafalgar Square",
"Santorini, Greece",
"Cappadocia, Turkey",
"Machu Picchu, Peru",
"Salar de Uyuni, Bolivia",
"Zhangjiajie National Forest Park, China",
"The Grand Canyon, Arizona, USA",
"Bora Bora, French Polynesia",
"The Great Barrier Reef, Australia",
"The Maldives",
"Angkor Wat, Cambodia",
"The Taj Mahal, Agra, India",
"The Pyramids of Giza, Egypt",
"Petra, Jordan",
"Marrakech, Morocco",
"Serengeti National Park, Tanzania",
"The Northern Lights, Norway",
"The Matterhorn, Switzerland",
"Plitvice Lakes National Park, Croatia",
"The Great Wall of China",
"The Eiffel Tower, Paris, France",
    "Central Park, New York City, USA",
    "Shibuya Crossing, Tokyo, Japan",
    "La Rambla, Barcelona, Spain",
    "The Louvre Museum, Paris, France",
    "The Colosseum, Rome, Italy",
    "Tower Bridge, London, UK",
    "Times Square, New York City, USA",
    "The Spanish Steps, Rome, Italy",
    "The Brooklyn Bridge, New York City, USA",
    "The Trevi Fountain, Rome, Italy",
    "The Palace of Versailles, Versailles, France",
    "The Guggenheim Museum, Bilbao, Spain",
    "The Santa Monica Pier, Santa Monica, USA",
    "The National Mall, Washington D.C., USA",
    "The Art Institute of Chicago, Chicago, USA",
    "The Brandenburg Gate, Berlin, Germany",
    "The Sydney Opera House, Sydney, Australia",
    "The Burj Khalifa, Dubai, UAE",
    "The Petronas Twin Towers, Kuala Lumpur, Malaysia",
    "The Marina Bay Sands, Singapore",
    "The Golden Gate Bridge, San Francisco, USA",
    "The Empire State Building, New York City, USA",
    "The London Eye, London, UK",
    "The Tower of London, London, UK",
    "The Arc de Triomphe, Paris, France",
    "The Notre-Dame Cathedral, Paris, France",
    "The Sagrada Familia, Barcelona, Spain",
    "The Alhambra, Granada, Spain",
    "The Grand Palace, Bangkok, Thailand",
    "The Forbidden City, Beijing, China",
    "The Tokyo Tower, Tokyo, Japan",
    "The Space Needle, Seattle, USA",
    "The Hollywood Sign, Los Angeles, USA",
    "The CN Tower, Toronto, Canada",
    "The Opera Garnier, Paris, France",
    "The Rijksmuseum, Amsterdam, Netherlands",
    "The Van Gogh Museum, Amsterdam, Netherlands",
    "The EYE Film Museum, Amsterdam, Netherlands",
    "The Charles Bridge, Prague, Czech Republic",
    "The Wawel Castle, Krakow, Poland",
    "The St. Stephen's Basilica, Budapest, Hungary",
    "The Parliament Building, Budapest, Hungary",
    "The La Scala Theater, Milan, Italy",
    "The San Francisco Cable Cars, San Francisco, USA",
    "The Santa Fe Art District, Denver, USA",
    "The Las Vegas Strip, Las Vegas, USA",
    "The Pike Place Market, Seattle, USA",
    "The Grand Bazaar, Istanbul, Turkey",
    "The Blue Mosque, Istanbul, Turkey",
    "The Basilica di San Marco, Venice, Italy",
    "The Pantheon, Rome, Italy",
    "The Piazza del Popolo, Rome, Italy",
    "The Piazza Navona, Rome, Italy",
    "The Piazza della Signoria, Florence, Italy",
    "The Uffizi Gallery, Florence, Italy",
    "The Leaning Tower of Pisa, Pisa, Italy",
    "The Piazza San Marco, Venice, Italy",
    "The Fisherman's Bastion, Budapest, Hungary",
    "The Park Güell, Barcelona, Spain",
    "The Royal Palace of Madrid, Madrid, Spain",
"The Colosseum, Rome, Italy",
"The Acropolis, Athens, Greece",
"The Cliffs of Moher, County Clare, Ireland",
"Edinburgh Castle, Edinburgh, Scotland",
"Neuschwanstein Castle, Bavaria, Germany",
"Mont Saint-Michel, Normandy, France",
"The Blue Lagoon, Iceland",
"The Vatican City, Rome, Italy",
"Yosemite National Park, California, USA",
"Glacier National Park, Montana, USA",
"Yellowstone National Park, Wyoming, USA",
"Grand Teton National Park, Wyoming, USA",
"The Rocky Mountains, Colorado, USA",
"Banff National Park, Alberta, Canada",
"Niagara Falls, Ontario, Canada/New York, USA",
"Machuca Village, Chile",
"Atacama Desert, Chile",
"Torres del Paine National Park, Chile",
"Iguazu Falls, Brazil/Argentina",
"Christ the Redeemer Statue, Rio de Janeiro, Brazil",
"Amazon Rainforest, Brazil",
"Cape of Good Hope, South Africa",
"Victoria Falls, Zambia/Zimbabwe",
"Okavango Delta, Botswana",
"Great Migration, Kenya/Tanzania",
"Wadden Sea, Netherlands/Germany/Denmark",
"Plitvice Lakes, Croatia",
"Hallstatt, Austria",
"Rila Monastery, Bulgaria",
"Lake Bled, Slovenia"]

# %%
import random, re


output = []
subject = []
artist = []
style = []
format = []
place = []
outfit = []
terragen = []
terrain = []

subject.extend(characters)
place.extend(photogenic_places)
place.extend(photogenic_places)
place.extend(fictional_places)
place.extend(fictional_places)
place.extend(vacation_places)
outfit.extend(outfits)
terragen.extend(terragens)
terrain.extend(terrains)

n=33

prompt_str  = 'SUBJECT wearing Terragen OUTFIT in PLACE, TERRAIN, TERRAGEN, photograph, hyperrealistic, photography, full body shot' 



for i in range(n):
    prompt = prompt_str + ' --v 5'  
    random_str = random.choice(subject)  
    prompt = re.sub(r'\bSUBJECT\b', random_str, prompt) 
    if len(terragen) > 0:
      random_str = random.choice(terragen)   
      prompt = re.sub(r'\bTERRAGEN\b', random_str, prompt) 
    else:   
      prompt =  re.sub(r'TERRAGEN', ' ', prompt, flags=re.IGNORECASE)
    if len(terrain) > 0:
      random_str = random.choice(terrain)   
      prompt = re.sub(r'\bTERRAIN\b', random_str, prompt) 
    else:   
      prompt = re.sub(r'\bTERRAIN\b', '', prompt)
    if len(place) > 0:
      random_str = random.choice(place)   
      prompt = re.sub(r'\bPLACE\b', random_str, prompt) 
    else:   
      prompt = re.sub(r'\bPLACE\b', '', prompt) 
    if len(outfit) > 0:
      random_str = random.choice(outfit)   
      prompt = re.sub(r'\bOUTFIT\b', random_str, prompt) 
    else:   
      prompt = re.sub(r'\bOUTFIT\b', '', prompt)           
    prompt = re.sub(r'[ ]+', ' ', prompt)     
    output.append(prompt)

for i in output:
  print(i)
# Out:
# Knuckles video game character wearing Terragen Cargo pants and tank top in Mont Saint-Michel, Normandy, France, Terragen Mars-like red planet, Terragen Delta Shifters | by Subterfugitive, photograph, hyperrealistic, photography, full body shot --v 5
# Wolverine wearing Terragen Tank top and maxi skirt in The Piazza San Marco, Venice, Italy, Terragen Sand dunes in a desert, Terragen Island Shifters | by Subterfugitive, photograph, hyperrealistic, photography, full body shot --v 5
# Bubble Bass wearing Terragen Long coat and boots in Machu Picchu, Peru, Terragen Lunar surface, Terragen Peninsula Shifters | by Subterfugitive, photograph, hyperrealistic, photography, full body shot --v 5
# Lara Croft Tomb Raider wearing Terragen A-line dress in Diagon Alley (Harry Potter), Terragen Gothic cathedral in a city, Terragen Hill Shifters | by Subterfugitive, photograph, hyperrealistic, photography, full body shot --v 5
# ...

# %% [markdown]
# ## Results
#
# <table>
#   <tr>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/rtnltbcmaru.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/zfqefnrikqi.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/hvirqmszvqy.png"></td>
#   </tr>
#   <tr>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/rmuyhcwubll.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/zanqbgelkie.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/nqqavagddif.png"></td>
#   </tr>
#   <tr>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/vcnkfrxybuy.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/tbwompifxut.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/oxuruaccvya.png"></td>
#   </tr>
#   <tr>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/kigptuyawnw.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/esoyjpvctzi.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/qkzgxwypeon.png"></td>
#   </tr>
#   <tr>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/rslclrnjrda.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/plsmydahmiq.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/zlcnvkifbht.png"></td>
#   </tr>
#   <tr>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/uffvpwuhsnt.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/zygvttxprsg.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/xirimrwjahc.png"></td>
#   </tr>
#   <tr>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/oeebrqfvhsr.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/jgfscwgtkay.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/bdpaauqaher.png"></td>
#   </tr>
#   <tr>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/tcjewpnsbnt.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/fmhuqzjivnj.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/ywbslgbahdo.png"></td>
#   </tr>
#   <tr>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/mtzeeqxmfrz.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/ylvmcmfpwfj.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/nrsqfkbcaxw.png"></td>
#   </tr>
#   <tr>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/mowworbnnfs.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/qxklhuqrtem.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/oeqfwqxfdrf.png"></td>
#   </tr>
#   <tr>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/ipzbhniwkgt.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/lrhyombrtkh.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/poosqaxvnfb.png"></td>
#   </tr>
#   <tr>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/wwtjnvxmgrr.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/jfpxsucluhs.png"></td>
#     <td><img src="https://raw.githubusercontent.com/aiskunks/Prompt_Engineering/main/Midjourney/SplitScreen/Art/lgeewyjwlfy.png"></td>
#   </tr>
# </table>
#
#  The Midjourney Split Screen keyword seems useful. More experiments down the road.
